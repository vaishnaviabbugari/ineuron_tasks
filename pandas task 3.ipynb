# %%
import pandas as pd

# %%
 fibit=pd.read_csv(r"C:\Users\user\Downloads\FitBit data.csv")

# %%
fitbit.head()
# Out:
# Empty DataFrame
# ...

# %%
type(fitbit)
# Out:
# pandas.core.frame.DataFrame

# %%
import mysql.connector as conn
mydb = conn.connect(host= "localhost", user = "root" , password  = "vaishnavi143")
cursor = mydb.cursor()

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import engine as sa
engine = sa.create_engine('mysql+pymysql://root:vaishnavi143@localhost/task')

# %%
fitbit.to_sql('task', con = engine)
# Out:
# 457

# %%
cursor.execute("use task")

# %%
pd.read_sql_query("select * from task",engine)
# Out:
#      index          Id ActivityDate  TotalSteps  TotalDistance  \
# 0        0  1503960366    3/25/2016       11004       7.110000
# 1        1  1503960366    3/26/2016       17609      11.550000
# 2        2  1503960366    3/27/2016       12736       8.530000
# 3        3  1503960366    3/28/2016       13231       8.930000
# 4        4  1503960366    3/29/2016       12041       7.850000
# ..     ...         ...          ...         ...            ...
# 452    452  8877689391     4/8/2016       23014      20.389999
# 453    453  8877689391     4/9/2016       16470       8.070000
# 454    454  8877689391    4/10/2016       28497      27.530001
# 455    455  8877689391    4/11/2016       10622       8.060000
# 456    456  8877689391    4/12/2016        2350       1.780000
#
#      TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0           7.110000                       0.0                2.57
# 1          11.550000                       0.0                6.92
# ...

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
import pandas as pd
client = pymongo.MongoClient("mongodb+srv://vaishnavi:vaishnavi143@cluster0.dssdymw.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
fitbit=pd.read_csv(r"C:\Users\user\Downloads\FitBit data.csv")
fitbit.to_json(r"C:\Users\user\Downloads\FitBit data.csv")

# %%
 fitbit.to_json
# Out:
# <bound method NDFrame.to_json of              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
# ...

# %%
database = client["task"]
collection = database['fitbit']
collection.insert_one(fitbit_jsonviewer)

# %%
fitbit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitbit["dateformat"]= pd.to_datetime(fitbit["ActivityDate"])

# %%
fitbit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitbit['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(fitbit["Id"].unique())
# Out:
# 35

# %%
fitbit["totalactive_minutes"]=fitbit["VeryActiveMinutes"]+fitbit["FairlyActiveMinutes"]+fitbit["LightlyActiveMinutes"]

# %%
fitbit.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitbit.groupby("Id")["totalactive_minutes"].sum()
# Out:
# Id
# 1503960366    5318
# 1624580081    2325
# 1644430081    2860
# 1844505072    1920
# 1927972279    1360
# 2022484408    3797
# 2026352035    2032
# 2320127002    1535
# 2347167796    4327
# 2873212765    3436
# 2891001357    2010
# 3372868164    3022
# 3977333714    3004
# 4020332650    4547
# 4057192912    1593
# 4319703577    3282
# 4388161847       0
# 4445114986    3099
# 4558609924    3083
# 4702921684    4004
# 5553957443    2683
# 5577150313    2940
# 6117666160    3045
# 6290855005     578
# 6391747486     361
# 6775888955    1738
# 6962181067    4521
# 7007744171    4061
# 7086361926    1742
# 8053475328    2756
# 8253242879     837
# 8378563200    2816
# 8583815059    1117
# 8792009665    1668
# 8877689391    3875
# Name: totalactive_minutes, dtype: int64

# %%
len(fitbit[fitbit["totalactive_minutes"]==0])
# Out:
# 68

# %%
fitbit(fitbit["totalactive_minutes"]==min(fitbit["totalactive_minutes"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 fitbit(fitbit["totalactive_minutes"]==min(fitbit["totalactive_minutes"]))
#
# TypeError: 'DataFrame' object is not callable
