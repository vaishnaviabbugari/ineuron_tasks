# %% [markdown]
# #                           EDA on google playstore data

# %%
#importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#reading dataset
df = pd.read_csv(r"E:\downloads\Dataset.zip-20221007T092337Z-001\Dataset\Dataset\data3\google_cleaned.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
#it tells us the shape of data ,columns and rows
df.shape
# Out:
# (10840, 16)

# %%
#df.sample gives the sample from whole dataset
df.sample(3)
# Out:
#                       App         Category  Rating  Reviews  Size  Installs  \
# 10063          Snes9x EX+             GAME     4.4    70351   NaN   5000000
# 7602   Adventure Time Run             GAME     4.3    24628  88.0   1000000
# 3381     Door Lock Screen  PERSONALIZATION     4.3     5413   3.9   1000000
#
#        Type  Price Content Rating           Genres Last Updated  \
# 10063  Free    0.0       Everyone           Arcade   2018-03-03
# 7602   Free    0.0       Everyone           Action   2018-07-26
# 3381   Free    0.0       Everyone  Personalization   2018-07-28
#
#               Current Ver         Android Ver  Day  Month  Year
# 10063  Varies with device  Varies with device    3      3  2018
# 7602             1.25.396          4.4 and up   26      7  2018
# 3381                3.3.a          4.0 and up   28      7  2018

# %%
#it gives all the information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
#checking if there are any missing values
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# Day                  0
# Month                0
# Year                 0
# dtype: int64

# %%
#total sum
df.isna().sum().sum()
# Out:
# 3180

# %%
#checking if there are any null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# Day                  0
# Month                0
# Year                 0
# dtype: int64

# %%
#total sum
df.isnull().sum().sum()
# Out:
# 3180

# %%
#describing data
df.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price  \
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.506534  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.596021  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.010000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000
#
#                 Day         Month          Year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# 25%        6.000000      5.000000   2017.000000
# ...

# %%
#transposed
df.describe().T
# Out:
#             count          mean           std      min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.00     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.00    38.0    2094.0
# Size       9145.0  2.150653e+01  2.259602e+01     0.01     4.9      13.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.00  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.00     0.0       0.0
# Day       10840.0  1.560904e+01  9.561621e+00     1.00     6.0      16.0
# Month     10840.0  6.422325e+00  2.578388e+00     1.00     5.0       7.0
# Year      10840.0  2.017400e+03  1.100914e+00  2010.00  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size           30.0  1.000000e+02
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# Day            24.0  3.100000e+01
# Month           8.0  1.200000e+01
# ...

# %% [markdown]
# # data cleaning

# %%
df.describe( include ="all")
# Out:
#            App Category       Rating       Reviews         Size      Installs  \
# count    10840    10840  9366.000000  1.084000e+04  9145.000000  1.084000e+04
# unique    9659       33          NaN           NaN          NaN           NaN
# top     ROBLOX   FAMILY          NaN           NaN          NaN           NaN
# freq         9     1972          NaN           NaN          NaN           NaN
# mean       NaN      NaN     4.191757  4.441529e+05    21.506534  1.546434e+07
# std        NaN      NaN     0.515219  2.927761e+06    22.596021  8.502936e+07
# min        NaN      NaN     1.000000  0.000000e+00     0.010000  0.000000e+00
# 25%        NaN      NaN     4.000000  3.800000e+01     4.900000  1.000000e+03
# 50%        NaN      NaN     4.300000  2.094000e+03    13.000000  1.000000e+05
# 75%        NaN      NaN     4.500000  5.477550e+04    30.000000  5.000000e+06
# max        NaN      NaN     5.000000  7.815831e+07   100.000000  1.000000e+09
#
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df['Reviews'].head()
# Out:
# 0       159
# 1       967
# 2     87510
# 3    215644
# 4       967
# Name: Reviews, dtype: int64

# %%
df['Reviews'].shape
# Out:
# (10840,)

# %%
df['Reviews'].dtype
# Out:
# dtype('int64')

# %%
df_copy = df.copy()

# %%
 ## There we are droping the index = 10472 from a dataset
df_copy = df_copy.drop(df_copy.index[10472])

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df_copy.shape
# Out:
# (10838, 16)

# %%
## Here we are Converting Dtpye from Object to 'Int'
df_copy['Reviews'] = df_copy['Reviews'].astype('int')

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Size'].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
import numpy as np

# %%
df_copy['Size'].dtype
# Out:
# dtype('float64')

# %%
df_copy['Size'] = df_copy['Size'].astype('float')

# %%
df_copy['Size'].dtype
# Out:
# dtype('float64')

# %%
df_copy['Size'].head()
# Out:
# 0    19.0
# 1    14.0
# 2     8.7
# 3    25.0
# 4     2.8
# Name: Size, dtype: float64

# %%
df_copy['Size'][2]*1000
# Out:
# 8700.0

# %%
 ## Here we are using Scaling Function
for i in df_copy['Size']:
    if i < 10 :
        df_copy['Size']= df_copy['Size'].replace(i, i*1000)

# %%
df_copy['Size'].head()
# Out:
# 0      19.0
# 1      14.0
# 2    8700.0
# 3      25.0
# 4    2800.0
# Name: Size, dtype: float64

# %%
df_copy['Size'].unique()
# Out:
# array([  19.,   14., 8700.,   25., 2800., 5600.,   29.,   33., 3100.,
#          28.,   12.,   20.,   21.,   37., 2700., 5500.,   17.,   39.,
#          31., 4200., 7000.,   23., 6000., 6100., 4600., 9200., 5200.,
#          11.,   24.,   nan, 9400.,   15.,   10., 1200.,   26., 8000.,
#        7900.,   56.,   57.,   35.,   54.,  201., 3600., 5700., 8600.,
#        2400.,   27., 2500.,   16., 3400., 8900., 3900., 2900.,   38.,
#          32., 5400.,   18., 1100., 2200., 4500., 9800.,   52., 9000.,
#        6700.,   30., 2600., 7100., 3700.,   22., 7400., 6400., 3200.,
#        8200., 9900., 4900., 9500., 5000., 5900.,   13.,   73., 6800.,
#        3500., 4000., 2300., 7200., 2100.,   42., 7300., 9100.,   55.,
#        6500., 1500., 7500.,   51.,   41.,   48., 8500.,   46., 8300.,
#        4300., 4700., 3300.,   40., 7800., 8800., 6600., 5100.,   61.,
#          66.,   79., 8400.,  118.,   44.,  695., 1600., 6200.,   53.,
# ...

# %%
 ## Here we are using Scaling Function
df_copy['Size'] = df_copy['Size']/1000

# %%
df_copy['Size'].head()
# Out:
# 0    0.019
# 1    0.014
# 2    8.700
# 3    0.025
# 4    2.800
# Name: Size, dtype: float64

# %%
df_copy['Size'].unique()
# Out:
# array([0.019, 0.014, 8.7  , 0.025, 2.8  , 5.6  , 0.029, 0.033, 3.1  ,
#        0.028, 0.012, 0.02 , 0.021, 0.037, 2.7  , 5.5  , 0.017, 0.039,
#        0.031, 4.2  , 7.   , 0.023, 6.   , 6.1  , 4.6  , 9.2  , 5.2  ,
#        0.011, 0.024,   nan, 9.4  , 0.015, 0.01 , 1.2  , 0.026, 8.   ,
#        7.9  , 0.056, 0.057, 0.035, 0.054, 0.201, 3.6  , 5.7  , 8.6  ,
#        2.4  , 0.027, 2.5  , 0.016, 3.4  , 8.9  , 3.9  , 2.9  , 0.038,
#        0.032, 5.4  , 0.018, 1.1  , 2.2  , 4.5  , 9.8  , 0.052, 9.   ,
#        6.7  , 0.03 , 2.6  , 7.1  , 3.7  , 0.022, 7.4  , 6.4  , 3.2  ,
#        8.2  , 9.9  , 4.9  , 9.5  , 5.   , 5.9  , 0.013, 0.073, 6.8  ,
#        3.5  , 4.   , 2.3  , 7.2  , 2.1  , 0.042, 7.3  , 9.1  , 0.055,
#        6.5  , 1.5  , 7.5  , 0.051, 0.041, 0.048, 8.5  , 0.046, 8.3  ,
#        4.3  , 4.7  , 3.3  , 0.04 , 7.8  , 8.8  , 6.6  , 5.1  , 0.061,
#        0.066, 0.079, 8.4  , 0.118, 0.044, 0.695, 1.6  , 6.2  , 0.053,
# ...

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
df_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews   Size  Installs  Type  Price Content Rating  \
# 0      159  0.019     10000  Free    0.0       Everyone
# 1      967  0.014    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
#
#    Month  Year
# 0      1  2018
# 1      1  2018

# %%
df_copy['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10835        5000
# 10836         100
# 10837        1000
# 10838        1000
# 10839    10000000
# Name: Installs, Length: 10838, dtype: int64

# %%
df_copy['Installs'].dtype
# Out:
# dtype('int64')

# %%
df_copy['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0],
#       dtype=int64)

# %%
chars_to_remove = ['+',',','$']
cols_to_clean = ['Installs', 'Price']

for item in chars_to_remove :
    for col in cols_to_clean:
        df_copy[col] = df_copy[col]

# %%
df_copy['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df_copy['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0],
#       dtype=int64)

# %%
df_copy['Installs'] = df_copy['Installs'].astype('int')

# %%
df_copy['Price'] = df_copy['Price'].astype('float')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10838 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10838 non-null  object
#  1   Category        10838 non-null  object
#  2   Rating          9364 non-null   float64
#  3   Reviews         10838 non-null  int32
#  4   Size            9143 non-null   float64
#  5   Installs        10838 non-null  int32
#  6   Type            10837 non-null  object
#  7   Price           10838 non-null  float64
#  8   Content Rating  10838 non-null  object
#  9   Genres          10838 non-null  object
#  10  Last Updated    10838 non-null  object
#  11  Current Ver     10830 non-null  object
#  12  Android Ver     10836 non-null  object
#  13  Day             10838 non-null  int64
#  14  Month           10838 non-null  int64
#  15  Year            10838 non-null  int64
# dtypes: float64(3), int32(2), int64(3), object(8)
# ...

# %%
df_copy.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews   Size  Installs  Type  Price Content Rating  \
# 0      159  0.019     10000  Free    0.0       Everyone
# 1      967  0.014    500000  Free    0.0       Everyone
# 2    87510  8.700   5000000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
# 2               Art & Design   2018-08-01       1.2.4  4.0.3 and up    1
#
#    Month  Year
# 0      1  2018
# 1      1  2018
# 2      8  2018

# %%
df_copy['Last Updated']
# Out:
# 0        2018-01-07
# 1        2018-01-15
# 2        2018-08-01
# 3        2018-06-08
# 4        2018-06-20
#             ...
# 10835    2017-07-25
# 10836    2018-07-06
# 10837    2017-01-20
# 10838    2015-01-19
# 10839    2018-07-25
# Name: Last Updated, Length: 10838, dtype: object

# %%
df_copy['Last Updated'].dtype
# Out:
# dtype('O')

# %%
df_copy['Last Updated'] = pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy['Last Updated'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_copy['Day'] = df_copy['Last Updated'].dt.day

# %%
df_copy['Month'] = df_copy['Last Updated'].dt.month

# %%
df_copy['Year'] = df_copy['Last Updated'].dt.year

# %%
df_copy.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews   Size  Installs  Type  Price Content Rating  \
# 0      159  0.019     10000  Free    0.0       Everyone
# 1      967  0.014    500000  Free    0.0       Everyone
# 2    87510  8.700   5000000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
# 2               Art & Design   2018-08-01       1.2.4  4.0.3 and up    1
#
#    Month  Year
# 0      1  2018
# 1      1  2018
# 2      8  2018

# %% [markdown]
# # Final Cleaned Dataset

# %%
df_copy.to_csv("google_cleaned.csv", index = False)

# %%
pd.read_csv("google_cleaned.csv")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                   Sya9a Maroc - FR               FAMILY
# 10834                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10835                             Parkinson Exercices FR              MEDICAL
# 10836                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10837      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.read_csv("google_cleaned.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10838 entries, 0 to 10837
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10838 non-null  object
#  1   Category        10838 non-null  object
#  2   Rating          9364 non-null   float64
#  3   Reviews         10838 non-null  int64
#  4   Size            9143 non-null   float64
#  5   Installs        10838 non-null  int64
#  6   Type            10837 non-null  object
#  7   Price           10838 non-null  float64
#  8   Content Rating  10838 non-null  object
#  9   Genres          10838 non-null  object
#  10  Last Updated    10838 non-null  object
#  11  Current Ver     10830 non-null  object
#  12  Android Ver     10836 non-null  object
#  13  Day             10838 non-null  int64
#  14  Month           10838 non-null  int64
#  15  Year            10838 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...
