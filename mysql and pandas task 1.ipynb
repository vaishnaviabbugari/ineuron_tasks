# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as connection

# %%
import pandas as pd

# %%
mydbase = connection.connect(host="localhost",user = "root",password="vaishnavi143")

# %%
cursor = mydbase.cursor()

# %%
print(mydbase)

# %%
sql_query1 = pd.read_sql("select * from mysql_task.attribute_data", mydbase)

# %%
print(sql_query1)
# Out:
#      1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless  \
# 0    1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
# 1    1212192089   Casual      Low  0.0     L  Summer     o-neck      Petal
# 2    1190380701  vintage     High  0.0     L  Automn     o-neck       full
# 3     966005983    Brief  Average  4.6     L  Spring     o-neck       full
# 4     876339541     cute      Low  4.5     M  Summer     o-neck  butterfly
# ..          ...      ...      ...  ...   ...     ...        ...        ...
# 497   532874347   Casual  Average  4.7     M  Summer     v-neck       full
# 498   655464934   Casual  Average  4.6     L  winter  boat-neck  sleevless
# 499   919930954   Casual      Low  4.4  free  Summer     v-neck      short
# 500  1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
# 501  1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
#
#       empire           null     chiffon     ruffles  animal  1
# ...

# %%
sql_query2 = pd.read_sql("select * from mysql_task.dress_sales",mydbase)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
print(sql_query2)
# Out:
#        dress_id  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
# ...

# %%
type(sql_query1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sql_query2)
# Out:
# pandas.core.frame.DataFrame

# %%
attribute_data = pd.DataFrame(sql_query1)

# %%
attribute_data
# Out:
#      1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless  \
# 0    1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
# 1    1212192089   Casual      Low  0.0     L  Summer     o-neck      Petal
# 2    1190380701  vintage     High  0.0     L  Automn     o-neck       full
# 3     966005983    Brief  Average  4.6     L  Spring     o-neck       full
# 4     876339541     cute      Low  4.5     M  Summer     o-neck  butterfly
# ..          ...      ...      ...  ...   ...     ...        ...        ...
# 497   532874347   Casual  Average  4.7     M  Summer     v-neck       full
# 498   655464934   Casual  Average  4.6     L  winter  boat-neck  sleevless
# 499   919930954   Casual      Low  4.4  free  Summer     v-neck      short
# 500  1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
# 501  1006032852     Sexy      Low  4.6     M  Summer     o-neck  sleevless
#
#       empire           null     chiffon     ruffles  animal  1
# ...

# %%
type(attribute_data)
# Out:
# pandas.core.frame.DataFrame

# %%
dress_sales = pd.DataFrame(sql_query2)

# %%
dress_sales
# Out:
#        dress_id  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
# ...

# %%
type(dress_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
attribute_data_json = attribute_data.to_json

# %%
attribute_data_json()
# Out:
# '{"1006032852":{"0":1006032852,"1":1212192089,"2":1190380701,"3":966005983,"4":876339541,"5":1068332458,"6":1220707172,"7":1219677488,"8":1113094204,"9":985292672,"10":1117293701,"11":898481530,"12":957723897,"13":749031896,"14":1055411544,"15":1162628131,"16":624314841,"17":830467746,"18":840857118,"19":1113221101,"20":861754372,"21":856178100,"22":1122989777,"23":840516484,"24":768517084,"25":1139843344,"26":1004212992,"27":1235426503,"28":942808364,"29":629131530,"30":851945460,"31":1150275464,"32":1026634314,"33":978773911,"34":827791337,"35":640823350,"36":801861988,"37":1060207186,"38":1054679816,"39":941190190,"40":943844640,"41":661795386,"42":875312593,"43":971387676,"44":1021185637,"45":1163826114,"46":735635595,"47":1175184188,"48":679415939,"49":884147971,"50":841203385,"51":1117997056,"52":1160536550,"53":828623528,"54":763708514,"55":1153442065,"56":743729613,"57":1000493051,"58":911085061,"59":1174854264,"60":1053296757,"61":1033843327,"62":1083779666,"63":746255172,"6
# ...

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
import json

# %%
client = pymongo.MongoClient("mongodb+srv://vaishnavi:vaishnavi143@cluster0.dssdymw.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-rbduoef-shard-00-01.dssdymw.mongodb.net:27017', 'ac-rbduoef-shard-00-00.dssdymw.mongodb.net:27017', 'ac-rbduoef-shard-00-02.dssdymw.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-qrir5k-shard-0', tls=True), 'test')

# %%
database = client['task']
collection = database['json']
print(json)
# Out:
# <module 'json' from 'C:\\Users\\user\\anaconda3\\lib\\json\\__init__.py'>

# %%
import mysql.connector as connection
mydbase = connection.connect(host="localhost",user = "root",password="vaishnavi143")
cursor=mydbase.cursor()
cursor.execute("select count(distinct(dress_id)) from mysql_task.dress_sales")
for i in cursor.fetchall():
        print(i)
# Out:
# (475,)

# %%
attribute_data.reco
