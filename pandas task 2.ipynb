# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\user\Downloads\AgentPerformance (1).xlsx',skiprows=1)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# 4                00:16:33            3.67               6

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df['date']=pd.to_datetime(df["Date"])

# %%
df['date_week']=df['date'].dt.isocalendar().week

# %%
df['date_days']=df['date'].dt.day

# %%
df_mean=df.groupby(['Agent Name','date_week'])['Average Rating'].mean().to_frame()

# %%
df_mean
# Out:
#                       Average Rating
# Agent Name date_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week  date_days
# 0         30         30
# 1         30         30
# 2         30         30
# ...

# %%
 df1 = df.groupby("Agent Name")["date_days"].count().to_frame()

# %%
df1.head()
# Out:
#                date_days
# Agent Name
# Abhishek              30
# Aditya                30
# Aditya Shinde         30
# Aditya_iot            30
# Amersh                30

# %%
df2 = df.groupby("Agent Name")["Total Chats"].sum().to_frame()

# %%
df2
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %%
df3 = df.groupby('Agent Name')['Total Feedback'].sum().to_frame()

# %%
df3.head()
# Out:
#                Total Feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0

# %%
df[(df['Average Rating']>3.5)&(df['Average Rating']<4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 76            Prateek _iot
# 78            Nandani Gupta
# 80            Jaydeep Dixit
#                ...
# 1869    Boktiar Ahmed Bappy
# 1874          Ayushi Mishra
# 1941         Jawala Prakash
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# Name: Agent Name, Length: 78, dtype: object

# %%
df[(df['Average Rating']<3.5)]["Agent Name"]
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %%
df[(df['Average Rating']>4.5)]["Agent Name"]
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %%
df.groupby("Agent Name")['Average Rating'].mean()>4.5
# Out:
# Agent Name
# Abhishek         False
# Aditya           False
# Aditya Shinde    False
# Aditya_iot       False
# Amersh           False
#                  ...
# Uday Mishra      False
# Vasanth P        False
# Vivek            False
# Wasim            False
# Zeeshan          False
# Name: Average Rating, Length: 70, dtype: bool

# %%
set(df["Agent Name"])
# Out:
# {'Abhishek ',
#  'Aditya ',
#  'Aditya Shinde',
#  'Aditya_iot ',
#  'Amersh ',
#  'Ameya Jain',
#  'Anirudh ',
#  'Ankit Sharma',
#  'Ankitjha ',
#  'Anurag Tiwari',
#  'Aravind ',
#  'Ashad Nasim',
#  'Ashish ',
#  'Ayushi Mishra',
#  'Bharath ',
#  'Boktiar Ahmed Bappy',
#  'Chaitra K Hiremath',
#  'Deepranjan Gupta',
#  'Dibyanshu ',
#  'Harikrishnan Shaji',
#  'Hitesh Choudhary',
#  'Hrisikesh Neogi',
#  'Hyder Abbas',
#  'Ineuron Intelligence ',
#  'Ishawant Kumar',
#  'Jawala Prakash',
#  'Jayant Kumar',
#  'Jaydeep Dixit',
#  'Khushboo Priya',
#  'Madhulika G',
#  'Mahak ',
#  'Mahesh Sarade',
#  'Maitry ',
#  'Maneesh ',
#  'Manjunatha A',
#  'Mithun S',
#  'Mukesh ',
#  'Mukesh Rao ',
#  'Muskan Garg',
#  'Nandani Gupta',
#  'Nishtha Jain',
#  'Nitin M',
#  'Prabir Kumar Satapathy',
#  'Prateek _iot ',
#  'Prerna Singh',
#  'Rishav Dash',
#  'Rohan ',
#  'Saif Khan',
#  'Saikumarreddy N',
#  'Samprit ',
#  'Sandipan Saha',
#  'Sanjeev Kumar',
#  'Sanjeevan ',
# ...

# %%
df.groupby(['Agent Name','Total Chats'])['Total Feedback'].sum()
# Out:
# Agent Name     Total Chats
# Abhishek       0               0
# Aditya         0               0
# Aditya Shinde  0               0
#                8               7
#                14              9
#                               ..
# Zeeshan        36             28
#                37             25
#                41             25
#                46             28
#                92             35
# Name: Total Feedback, Length: 638, dtype: int64

# %%
pd.read_excel(r"C:\Users\user\Downloads\Agent_Login_Report.xls",skiprows=1)
# Out:
#      Unnamed: 0          Unnamed: 1 Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 0         SL No               Agent       Date   Login Time  Logout Time
# 1             1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM
# 2             2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM
# 3             3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM
# 4             4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM
# ...         ...                 ...        ...          ...          ...
# 996         996        Manjunatha A  20-Jul-22  09:03:51 AM  03:02:28 PM
# 997         997            Bharath   20-Jul-22  09:00:49 AM  03:01:32 PM
# 998         998      Khushboo Priya  20-Jul-22  08:59:20 AM  02:26:55 PM
# 999         999        Nishtha Jain  20-Jul-22  08:43:55 AM  02:00:33 PM
# 1000       1000              Tarun   01-Jul-22  01:52:47 AM  12:01:07 PM
#
#      Unnamed: 5
# 0      Duration
# 1      02:04:10
# 2      00:00:17
# 3      02:26:42
# ...
